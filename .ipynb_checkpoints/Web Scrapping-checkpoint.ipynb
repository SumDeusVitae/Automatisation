# %%
# !pip install pandas

# %%
import pandas as pd

# %%
assault_rifles_site = pd.read_html('https://pubg.fandom.com/wiki/Assault_Rifles')

# %%
len(assault_rifles)
# Out:
# 5

# %%
assault_rifles_tab = assault_rifles_site[1]

# %%
#rename columns
assault_rifles_tab.rename(columns={'BDMG 0':'No Armor', 
                           'BDMG 1':'Armor 1',
                           'BDMG 2':'Armor 2',
                           'BDMG 3':'Armor 3',
                           'HDMG 0':'No Helm',
                           'HDMG 1':'Helm 1',
                           'HDMG 2':'Helm 2',
                           'HDMG 3':'Helm 3',}, inplace=True)

# %%
# for col in assault_rifles_tab.columns:
#     print(col)
assault_rifles_tab.drop(['PWR','zRNG','BSHT','CAP','BDEL','Image'], axis=1)
# Out:
#            Name  DMG      SPD   MAG      TBS                 Mode     AMM  \
# 0         ACE32   43  720 m/s  30.0   0.088s         Single, Auto  7.62mm
# 1           AKM   47  715 m/s  30.0   0.100s         Single, Auto  7.62mm
# 2        AUG A3   41  940 m/s  30.0  0.08571         Single, Auto  5.56mm
# 3    Beryl M762   44  740 m/s  30.0   0.086s  Single, Burst, Auto  7.62mm
# 4          G36C   41  870 m/s  30.0   0.086s         Single, Auto  5.56mm
# 5         Groza   47  715 m/s  30.0   0.080s         Single, Auto  7.62mm
# 6            K2   41      NaN   NaN      NaN                  NaN  5.56mm
# 7         M16A4   43  900 m/s  30.0   0.075s        Single, burst  5.56mm
# 8          M416   40  780 m/s  30.0   0.086s         Single, Auto  5.56mm
# 9   Mk47 Mutant   49  780 m/s  20.0   0.100s        Single, Burst  7.62mm
# 10        QBZ95   41  870 m/s  30.0   0.092s         Single, Auto  5.56mm
# 11       SCAR-L   41  870 m/s  30.0   0.096s         Single, Auto  5.56mm
#
# ...
